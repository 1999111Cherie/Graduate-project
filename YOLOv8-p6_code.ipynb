# %%
# !pip install spicy

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.1/874.1 kB 6.0 MB/s eta 0:00:00
# ...

# %%
# 压缩文件夹为 ZIP 文件
# !zip -r P6_epoch150_result.zip /content/runs/train/raw5

# 下载文件夹
from google.colab import files
files.download('P6_epoch150_result.zip')
# Out:
#   adding: content/runs/train/raw5/ (stored 0%)
#   adding: content/runs/train/raw5/val_batch1_labels.jpg (deflated 7%)
#   adding: content/runs/train/raw5/train_batch1.jpg (deflated 6%)
#   adding: content/runs/train/raw5/BoxR_curve.png (deflated 11%)
#   adding: content/runs/train/raw5/weights/ (stored 0%)
#   adding: content/runs/train/raw5/weights/last.pt (deflated 11%)
#   adding: content/runs/train/raw5/weights/best.pt (deflated 11%)
#   adding: content/runs/train/raw5/BoxPR_curve.png (deflated 9%)
#   adding: content/runs/train/raw5/val_batch1_pred.jpg (deflated 7%)
#   adding: content/runs/train/raw5/confusion_matrix.png (deflated 18%)
#   adding: content/runs/train/raw5/labels.jpg (deflated 25%)
#   adding: content/runs/train/raw5/BoxP_curve.png (deflated 8%)
#   adding: content/runs/train/raw5/labels_correlogram.jpg (deflated 34%)
#   adding: content/runs/train/raw5/MaskPR_curve.png (deflated 9%)
#   adding: content/runs/train/raw5/MaskF1_curve.png (deflated 11%)
# ...

# %% [markdown]
# About YOLOv8n-**p6**

# %%
# !python /content/ultralytics/train.py #epoch=100
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.2.96 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.94 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !python /content/ultralytics/train.py #epoch=150
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.2.96 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.94 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...
